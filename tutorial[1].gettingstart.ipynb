-- %%
require 'nn'
lena = image.lena()
lena = image.scale(lena, 256)
print(#lena)
gylena = image.rgb2y(lena)
-- Out:
--    3
--  256
--  256
-- [torch.LongStorage of size 3]

-- %%
conv1 = nn.SpatialConvolution(1,9,13,13)
output = conv1:forward(gylena)

-- %%
itorch.image(conv1.weight:view(9,1,13,13))
-- Out:
-- Console does not support images

-- %%
itorch.image(output:view(9,1,244,244))
-- Out:
-- Console does not support images

-- %%
mean = lena:mean();
stdv = lena:std();
print(mean,stdv)
itorch.image(lena)
norm = lena:add(-mean):div(stdv)
-- Out:
-- 0.37114959009849	0.208381592515
-- Console does not support images

-- %%
norm:min()
-- Out:
-- -1.4799987111452

-- %%
image.w
